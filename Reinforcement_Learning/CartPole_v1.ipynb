# %%
import numpy as np
import matplotlib.pyplot as plt
# %matplotlib inline
import gym

#宣告繪製動畫的函數
from JSAnimation.IPython_display import display_animation
from matplotlib import animation
from IPython.display import display

def display_frames_as_gif(frames):
    plt.figure(figsize=(frames[0].shape[1]/72.0, frames[0].shape[0]/72.0),dpi=72)
    patch=plt.imshow(frames[0])
    plt.axis('off')

    def animate(i):
        patch.set_data(frames[i])
    anim=animation.FuncAnimation(plt.gcf(),animate,frames=len(frames), interval=50)

    anim.save('movie_cartpole.mp4')
    display(display_animation(anim, default_mode='loop'))

#設定常數
Env='CartPole-v1'
num_discrete=6
Gamma=0.99
eta=0.5
max_step=1000
num_episode=10000

# %%
class Agent:
    def __init__(self, num_states,num_actions):
        self.brain=Brain(num_states,num_actions)
    def update_Q_function(self,observation,action,reward,observation_next):
        self.brain.update_Q_table(observation,action,reward,observation_next)
    def get_action(self,observation,step):
        action=self.brain.decide_action(observation,step)
        return action

# %%
class Brain:
    def __init__(self,num_states,num_actions):
        self.num_actions=num_actions
        self.q_table=np.random.uniform(low=0, high=1, size=(num_discrete**num_states,num_actions))

    #計算離散化
    def discrete(self,min,max,num):
        return np.linspace(min,max,num+1)[1:-1]

    def discrete_state(self,observation):
        cart_pos, cart_v, pole_angle, pole_v=observation
        discrete=[
            np.digitize(cart_pos,bins=self.discrete(-2.4,2.4, num_discrete)),
            np.digitize(cart_v,bins=self.discrete(-3.0,3.0, num_discrete)),
            np.digitize(pole_angle,bins=self.discrete(-0.5,0.5, num_discrete)),
            np.digitize(pole_v,bins=self.discrete(-2.0,2.0, num_discrete)),
        ]
        return sum([x*(num_discrete**i) for i, x in enumerate(discrete)])
        
    def update_Q_table(self,observation,action,reward, observation_next):
        state=self.discrete_state(observation)
        state_next=self.discrete_state(observation_next)

        Max_Q_next=max(self.q_table[state_next][:])
        self.q_table[state,action]=self.q_table[state,action]+eta*(reward+Gamma*Max_Q_next-self.q_table[state,action])

    def decide_action(self,observation,episode):
        state=self.discrete_state(observation)
        epsilon=(0.5)*(1/(episode+1))

        if epsilon<= np.random.rand(): #用random.uniform(0,1)訓練一直不成功，改成rand()就ok了
            action=np.argmax(self.q_table[state][:])
        else:
            action=np.random.choice(self.num_actions)
        return action

# %%
class Environment:
    def __init__(self):
        self.env=gym.make(Env,render_mode="rgb_array")
        num_states=self.env.observation_space.shape[0]
        num_actions=self.env.action_space.n

        self.agent=Agent(num_states,num_actions)
    def run(self):
        complete_episodes=0
        is_final=False
        frames=[]

        for episode in range(num_episode):
            observation, info=self.env.reset()
            
            for step in range(max_step):
                if is_final is True:
                    frames.append(self.env.render())
                    
                action=self.agent.get_action(observation,episode)

                observation_next,_,done,_,_=self.env.step(action)

                if done:
                    if step<200:
                        reward=-1
                        complete_episodes=0
                    else:
                        reward=1
                        complete_episodes+=1
                else:
                    reward=0

                self.agent.update_Q_function(observation,action,reward,observation_next)

                observation=observation_next

                if done:
                    print('{0} Episode: Finished after {1} steps'.format(episode,step+1))
                    break
                
            if is_final is True and step>=300:
                display_frames_as_gif(frames)
                break
            if complete_episodes>=15:
                print('連續成功15次!')
                is_final=True

# %%
#Main
cartpole_env=Environment()
cartpole_env.run()
# Out:
# /opt/anaconda3/envs/RL_env/lib/python3.11/site-packages/gym/utils/passive_env_checker.py:233: DeprecationWarning: `np.bool8` is a deprecated alias for `np.bool_`.  (Deprecated NumPy 1.24)
#   if not isinstance(terminated, (bool, np.bool8)):
# 0 Episode: Finished after 40 steps
# 1 Episode: Finished after 17 steps
# 2 Episode: Finished after 42 steps
# 3 Episode: Finished after 10 steps
# 4 Episode: Finished after 12 steps
# 5 Episode: Finished after 45 steps
# 6 Episode: Finished after 13 steps
# 7 Episode: Finished after 32 steps
# 8 Episode: Finished after 28 steps
# 9 Episode: Finished after 32 steps
# 10 Episode: Finished after 57 steps
# 11 Episode: Finished after 27 steps
# 12 Episode: Finished after 58 steps
# 13 Episode: Finished after 18 steps
# 14 Episode: Finished after 14 steps
# 15 Episode: Finished after 14 steps
# 16 Episode: Finished after 32 steps
# 17 Episode: Finished after 17 steps
# 18 Episode: Finished after 19 steps
# 19 Episode: Finished after 31 steps
# 20 Episode: Finished after 10 steps
# 21 Episode: Finished after 10 steps
# 22 Episode: Finished after 12 steps
# 23 Episode: Finished after 10 steps
# 24 Episode: Finished after 26 steps
# 25 Episode: Finished after 11 steps
# 26 Episode: Finished after 36 steps
# 27 Episode: Finished after 17 steps
# 28 Episode: Finished after 46 steps
# 29 Episode: Finished after 11 steps
# 30 Episode: Finished after 40 steps
# 31 Episode: Finished after 14 steps
# 32 Episode: Finished after 55 steps
# 33 Episode: Finished after 46 steps
# 34 Episode: Finished after 42 steps
# 35 Episode: Finished after 59 steps
# 36 Episode: Finished after 39 steps
# 37 Episode: Finished after 9 steps
# 38 Episode: Finished after 45 steps
# 39 Episode: Finished after 44 steps
# 40 Episode: Finished after 11 steps
# 41 Episode: Finished after 43 steps
# 42 Episode: Finished after 14 steps
# 43 Episode: Finished after 11 steps
# 44 Episode: Finished after 57 steps
# 45 Episode: Finished after 61 steps
# 46 Episode: Finished after 8 steps
# 47 Episode: Finished after 37 steps
# 48 Episode: Finished after 35 steps
# 49 Episode: Finished after 76 steps
# 50 Episode: Finished after 23 steps
# 51 Episode: Finished after 12 steps
# 52 Episode: Finished after 15 steps
# 53 Episode: Finished after 33 steps
# 54 Episode: Finished after 9 steps
# 55 Episode: Finished after 24 steps
# 56 Episode: Finished after 38 steps
# 57 Episode: Finished after 29 steps
# 58 Episode: Finished after 14 steps
# 59 Episode: Finished after 35 steps
# 60 Episode: Finished after 12 steps
# 61 Episode: Finished after 34 steps
# 62 Episode: Finished after 31 steps
# 63 Episode: Finished after 17 steps
# 64 Episode: Finished after 30 steps
# 65 Episode: Finished after 17 steps
# 66 Episode: Finished after 44 steps
# 67 Episode: Finished after 21 steps
# 68 Episode: Finished after 89 steps
# 69 Episode: Finished after 80 steps
# 70 Episode: Finished after 47 steps
# 71 Episode: Finished after 153 steps
# 72 Episode: Finished after 53 steps
# 73 Episode: Finished after 24 steps
# 74 Episode: Finished after 93 steps
# 75 Episode: Finished after 99 steps
# 76 Episode: Finished after 11 steps
# 77 Episode: Finished after 12 steps
# 78 Episode: Finished after 142 steps
# 79 Episode: Finished after 129 steps
# 80 Episode: Finished after 75 steps
# 81 Episode: Finished after 314 steps
# 82 Episode: Finished after 18 steps
# 83 Episode: Finished after 14 steps
# 84 Episode: Finished after 199 steps
# 85 Episode: Finished after 47 steps
# 86 Episode: Finished after 41 steps
# 87 Episode: Finished after 86 steps
# 88 Episode: Finished after 218 steps
# 89 Episode: Finished after 91 steps
# 90 Episode: Finished after 124 steps
# 91 Episode: Finished after 123 steps
# 92 Episode: Finished after 122 steps
# 93 Episode: Finished after 173 steps
# 94 Episode: Finished after 190 steps
# 95 Episode: Finished after 121 steps
# 96 Episode: Finished after 11 steps
# 97 Episode: Finished after 121 steps
# 98 Episode: Finished after 217 steps
# 99 Episode: Finished after 172 steps
# 100 Episode: Finished after 197 steps
# 101 Episode: Finished after 133 steps
# 102 Episode: Finished after 122 steps
# 103 Episode: Finished after 125 steps
# 104 Episode: Finished after 411 steps
# 105 Episode: Finished after 340 steps
# 106 Episode: Finished after 239 steps
# 107 Episode: Finished after 66 steps
# 108 Episode: Finished after 94 steps
# 109 Episode: Finished after 109 steps
# 110 Episode: Finished after 453 steps
# 111 Episode: Finished after 212 steps
# 112 Episode: Finished after 37 steps
# 113 Episode: Finished after 138 steps
# 114 Episode: Finished after 190 steps
# 115 Episode: Finished after 140 steps
# 116 Episode: Finished after 118 steps
# 117 Episode: Finished after 173 steps
# 118 Episode: Finished after 132 steps
# 119 Episode: Finished after 65 steps
# 120 Episode: Finished after 87 steps
# 121 Episode: Finished after 108 steps
# 122 Episode: Finished after 70 steps
# 123 Episode: Finished after 70 steps
# 124 Episode: Finished after 112 steps
# 125 Episode: Finished after 158 steps
# 126 Episode: Finished after 45 steps
# 127 Episode: Finished after 73 steps
# 128 Episode: Finished after 248 steps
# 129 Episode: Finished after 183 steps
# 130 Episode: Finished after 15 steps
# 131 Episode: Finished after 64 steps
# 132 Episode: Finished after 174 steps
# 133 Episode: Finished after 170 steps
# 134 Episode: Finished after 102 steps
# 135 Episode: Finished after 164 steps
# 136 Episode: Finished after 244 steps
# 137 Episode: Finished after 119 steps
# 138 Episode: Finished after 165 steps
# 139 Episode: Finished after 48 steps
# 140 Episode: Finished after 60 steps
# 141 Episode: Finished after 246 steps
# 142 Episode: Finished after 94 steps
# 143 Episode: Finished after 118 steps
# 144 Episode: Finished after 201 steps
# 145 Episode: Finished after 112 steps
# 146 Episode: Finished after 130 steps
# 147 Episode: Finished after 95 steps
# 148 Episode: Finished after 268 steps
# 149 Episode: Finished after 245 steps
# 150 Episode: Finished after 260 steps
# 151 Episode: Finished after 154 steps
# 152 Episode: Finished after 70 steps
# 153 Episode: Finished after 151 steps
# 154 Episode: Finished after 58 steps
# 155 Episode: Finished after 102 steps
# 156 Episode: Finished after 151 steps
# 157 Episode: Finished after 40 steps
# 158 Episode: Finished after 129 steps
# 159 Episode: Finished after 143 steps
# 160 Episode: Finished after 73 steps
# 161 Episode: Finished after 69 steps
# 162 Episode: Finished after 264 steps
# 163 Episode: Finished after 196 steps
# 164 Episode: Finished after 366 steps
# 165 Episode: Finished after 145 steps
# 166 Episode: Finished after 103 steps
# 167 Episode: Finished after 169 steps
# 168 Episode: Finished after 132 steps
# 169 Episode: Finished after 139 steps
# 170 Episode: Finished after 180 steps
# 171 Episode: Finished after 149 steps
# 172 Episode: Finished after 46 steps
# 173 Episode: Finished after 118 steps
# 174 Episode: Finished after 76 steps
# 175 Episode: Finished after 112 steps
# 176 Episode: Finished after 144 steps
# 177 Episode: Finished after 131 steps
# 178 Episode: Finished after 402 steps
# 179 Episode: Finished after 301 steps
# 180 Episode: Finished after 735 steps
# 181 Episode: Finished after 71 steps
# 182 Episode: Finished after 322 steps
# 183 Episode: Finished after 140 steps
# 184 Episode: Finished after 205 steps
# 185 Episode: Finished after 182 steps
# 186 Episode: Finished after 123 steps
# 187 Episode: Finished after 99 steps
# 188 Episode: Finished after 56 steps
# 189 Episode: Finished after 163 steps
# 190 Episode: Finished after 39 steps
# 191 Episode: Finished after 93 steps
# 192 Episode: Finished after 118 steps
# 193 Episode: Finished after 123 steps
# 194 Episode: Finished after 150 steps
# 195 Episode: Finished after 151 steps
# 196 Episode: Finished after 191 steps
# 197 Episode: Finished after 180 steps
# 198 Episode: Finished after 108 steps
# 199 Episode: Finished after 119 steps
# 200 Episode: Finished after 145 steps
# 201 Episode: Finished after 119 steps
# 202 Episode: Finished after 152 steps
# 203 Episode: Finished after 123 steps
# 204 Episode: Finished after 124 steps
# 205 Episode: Finished after 186 steps
# 206 Episode: Finished after 218 steps
# 207 Episode: Finished after 177 steps
# 208 Episode: Finished after 185 steps
# 209 Episode: Finished after 177 steps
# 210 Episode: Finished after 620 steps
# 211 Episode: Finished after 221 steps
# 212 Episode: Finished after 232 steps
# 213 Episode: Finished after 172 steps
# 214 Episode: Finished after 323 steps
# 215 Episode: Finished after 232 steps
# 216 Episode: Finished after 325 steps
# 217 Episode: Finished after 297 steps
# 218 Episode: Finished after 397 steps
# 219 Episode: Finished after 245 steps
# 220 Episode: Finished after 159 steps
# 221 Episode: Finished after 216 steps
# 222 Episode: Finished after 143 steps
# 223 Episode: Finished after 86 steps
# 224 Episode: Finished after 761 steps
# 225 Episode: Finished after 321 steps
# 226 Episode: Finished after 372 steps
# 227 Episode: Finished after 213 steps
# 228 Episode: Finished after 681 steps
# 229 Episode: Finished after 64 steps
# 230 Episode: Finished after 101 steps
# 231 Episode: Finished after 196 steps
# 232 Episode: Finished after 83 steps
# 233 Episode: Finished after 63 steps
# 234 Episode: Finished after 79 steps
# 235 Episode: Finished after 159 steps
# 236 Episode: Finished after 176 steps
# 237 Episode: Finished after 162 steps
# 238 Episode: Finished after 187 steps
# 239 Episode: Finished after 133 steps
# 240 Episode: Finished after 77 steps
# 241 Episode: Finished after 175 steps
# 242 Episode: Finished after 41 steps
# 243 Episode: Finished after 36 steps
# 244 Episode: Finished after 60 steps
# 245 Episode: Finished after 79 steps
# 246 Episode: Finished after 34 steps
# 247 Episode: Finished after 159 steps
# 248 Episode: Finished after 151 steps
# 249 Episode: Finished after 187 steps
# 250 Episode: Finished after 202 steps
# 251 Episode: Finished after 30 steps
# 252 Episode: Finished after 173 steps
# 253 Episode: Finished after 130 steps
# 254 Episode: Finished after 176 steps
# 255 Episode: Finished after 200 steps
# 256 Episode: Finished after 192 steps
# 257 Episode: Finished after 182 steps
# 258 Episode: Finished after 136 steps
# 259 Episode: Finished after 422 steps
# 260 Episode: Finished after 180 steps
# 261 Episode: Finished after 191 steps
# 262 Episode: Finished after 98 steps
# 263 Episode: Finished after 271 steps
# 264 Episode: Finished after 98 steps
# 265 Episode: Finished after 148 steps
# 266 Episode: Finished after 173 steps
# 267 Episode: Finished after 158 steps
# 268 Episode: Finished after 142 steps
# 269 Episode: Finished after 244 steps
# 270 Episode: Finished after 271 steps
# 271 Episode: Finished after 204 steps
# 272 Episode: Finished after 210 steps
# 273 Episode: Finished after 297 steps
# 274 Episode: Finished after 127 steps
# 275 Episode: Finished after 142 steps
# 276 Episode: Finished after 159 steps
# 277 Episode: Finished after 243 steps
# 278 Episode: Finished after 188 steps
# 279 Episode: Finished after 205 steps
# 280 Episode: Finished after 92 steps
# 281 Episode: Finished after 219 steps
# 282 Episode: Finished after 144 steps
# 283 Episode: Finished after 175 steps
# 284 Episode: Finished after 324 steps
# 285 Episode: Finished after 519 steps
# 286 Episode: Finished after 212 steps
# 287 Episode: Finished after 149 steps
# 288 Episode: Finished after 234 steps
# 289 Episode: Finished after 158 steps
# 290 Episode: Finished after 200 steps
# 291 Episode: Finished after 298 steps
# 292 Episode: Finished after 212 steps
# 293 Episode: Finished after 199 steps
# 294 Episode: Finished after 200 steps
# 295 Episode: Finished after 196 steps
# 296 Episode: Finished after 270 steps
# 297 Episode: Finished after 171 steps
# 298 Episode: Finished after 275 steps
# 299 Episode: Finished after 135 steps
# 300 Episode: Finished after 381 steps
# 301 Episode: Finished after 259 steps
# 302 Episode: Finished after 162 steps
# 303 Episode: Finished after 167 steps
# 304 Episode: Finished after 226 steps
# 305 Episode: Finished after 194 steps
# 306 Episode: Finished after 178 steps
# 307 Episode: Finished after 523 steps
# 308 Episode: Finished after 252 steps
# 309 Episode: Finished after 156 steps
# 310 Episode: Finished after 164 steps
# 311 Episode: Finished after 300 steps
# 312 Episode: Finished after 183 steps
# 313 Episode: Finished after 214 steps
# 314 Episode: Finished after 255 steps
# 315 Episode: Finished after 290 steps
# 316 Episode: Finished after 296 steps
# 317 Episode: Finished after 148 steps
# 318 Episode: Finished after 161 steps
# 319 Episode: Finished after 126 steps
# 320 Episode: Finished after 140 steps
# 321 Episode: Finished after 220 steps
# 322 Episode: Finished after 336 steps
# 323 Episode: Finished after 220 steps
# 324 Episode: Finished after 166 steps
# 325 Episode: Finished after 139 steps
# 326 Episode: Finished after 418 steps
# 327 Episode: Finished after 307 steps
# 328 Episode: Finished after 116 steps
# 329 Episode: Finished after 175 steps
# 330 Episode: Finished after 144 steps
# 331 Episode: Finished after 219 steps
# 332 Episode: Finished after 228 steps
# 333 Episode: Finished after 436 steps
# 334 Episode: Finished after 487 steps
# 335 Episode: Finished after 160 steps
# 336 Episode: Finished after 253 steps
# 337 Episode: Finished after 177 steps
# 338 Episode: Finished after 382 steps
# 339 Episode: Finished after 245 steps
# 340 Episode: Finished after 417 steps
# 341 Episode: Finished after 192 steps
# 342 Episode: Finished after 128 steps
# 343 Episode: Finished after 238 steps
# 344 Episode: Finished after 143 steps
# 345 Episode: Finished after 203 steps
# 346 Episode: Finished after 172 steps
# 347 Episode: Finished after 207 steps
# 348 Episode: Finished after 259 steps
# 349 Episode: Finished after 109 steps
# 350 Episode: Finished after 162 steps
# 351 Episode: Finished after 251 steps
# 352 Episode: Finished after 205 steps
# 353 Episode: Finished after 240 steps
# 354 Episode: Finished after 267 steps
# 355 Episode: Finished after 169 steps
# 356 Episode: Finished after 296 steps
# 357 Episode: Finished after 35 steps
# 358 Episode: Finished after 121 steps
# 359 Episode: Finished after 66 steps
# 360 Episode: Finished after 319 steps
# 361 Episode: Finished after 157 steps
# 362 Episode: Finished after 340 steps
# 363 Episode: Finished after 190 steps
# 364 Episode: Finished after 287 steps
# 365 Episode: Finished after 137 steps
# 366 Episode: Finished after 194 steps
# 367 Episode: Finished after 187 steps
# 368 Episode: Finished after 148 steps
# 369 Episode: Finished after 462 steps
# 370 Episode: Finished after 97 steps
# 371 Episode: Finished after 185 steps
# 372 Episode: Finished after 200 steps
# 373 Episode: Finished after 194 steps
# 374 Episode: Finished after 55 steps
# 375 Episode: Finished after 190 steps
# 376 Episode: Finished after 339 steps
# 377 Episode: Finished after 164 steps
# 378 Episode: Finished after 197 steps
# 379 Episode: Finished after 178 steps
# 380 Episode: Finished after 147 steps
# 381 Episode: Finished after 216 steps
# 382 Episode: Finished after 220 steps
# 383 Episode: Finished after 211 steps
# 384 Episode: Finished after 190 steps
# 385 Episode: Finished after 226 steps
# 386 Episode: Finished after 317 steps
# 387 Episode: Finished after 187 steps
# 388 Episode: Finished after 214 steps
# 389 Episode: Finished after 185 steps
# 390 Episode: Finished after 233 steps
# 391 Episode: Finished after 265 steps
# 392 Episode: Finished after 221 steps
# 393 Episode: Finished after 527 steps
# 394 Episode: Finished after 255 steps
# 395 Episode: Finished after 349 steps
# 396 Episode: Finished after 520 steps
# 397 Episode: Finished after 565 steps
# 398 Episode: Finished after 381 steps
# 399 Episode: Finished after 232 steps
# 400 Episode: Finished after 326 steps
# 401 Episode: Finished after 203 steps
# 402 Episode: Finished after 143 steps
# 403 Episode: Finished after 188 steps
# 404 Episode: Finished after 295 steps
# 405 Episode: Finished after 16 steps
# 406 Episode: Finished after 12 steps
# 407 Episode: Finished after 868 steps
# 408 Episode: Finished after 191 steps
# 409 Episode: Finished after 656 steps
# 410 Episode: Finished after 481 steps
# 411 Episode: Finished after 355 steps
# 412 Episode: Finished after 105 steps
# 413 Episode: Finished after 119 steps
# 414 Episode: Finished after 178 steps
# 415 Episode: Finished after 122 steps
# 416 Episode: Finished after 188 steps
# 417 Episode: Finished after 201 steps
# 418 Episode: Finished after 180 steps
# 419 Episode: Finished after 181 steps
# 420 Episode: Finished after 185 steps
# 421 Episode: Finished after 203 steps
# 422 Episode: Finished after 108 steps
# 423 Episode: Finished after 188 steps
# 424 Episode: Finished after 158 steps
# 425 Episode: Finished after 228 steps
# 426 Episode: Finished after 160 steps
# 427 Episode: Finished after 338 steps
# 428 Episode: Finished after 468 steps
# 429 Episode: Finished after 614 steps
# 430 Episode: Finished after 263 steps
# 431 Episode: Finished after 431 steps
# 432 Episode: Finished after 233 steps
# 433 Episode: Finished after 258 steps
# 434 Episode: Finished after 134 steps
# 435 Episode: Finished after 186 steps
# 436 Episode: Finished after 517 steps
# 437 Episode: Finished after 276 steps
# 438 Episode: Finished after 243 steps
# 439 Episode: Finished after 177 steps
# 440 Episode: Finished after 240 steps
# 441 Episode: Finished after 114 steps
# 442 Episode: Finished after 320 steps
# 443 Episode: Finished after 121 steps
# 444 Episode: Finished after 261 steps
# 445 Episode: Finished after 162 steps
# 446 Episode: Finished after 326 steps
# 447 Episode: Finished after 242 steps
# 448 Episode: Finished after 153 steps
# 449 Episode: Finished after 180 steps
# 450 Episode: Finished after 223 steps
# 451 Episode: Finished after 305 steps
# 452 Episode: Finished after 231 steps
# 453 Episode: Finished after 117 steps
# 454 Episode: Finished after 177 steps
# 455 Episode: Finished after 226 steps
# 456 Episode: Finished after 252 steps
# 457 Episode: Finished after 325 steps
# 458 Episode: Finished after 315 steps
# 459 Episode: Finished after 488 steps
# 460 Episode: Finished after 451 steps
# 461 Episode: Finished after 386 steps
# 462 Episode: Finished after 186 steps
# 463 Episode: Finished after 206 steps
# 464 Episode: Finished after 210 steps
# 465 Episode: Finished after 124 steps
# 466 Episode: Finished after 196 steps
# 467 Episode: Finished after 143 steps
# 468 Episode: Finished after 302 steps
# 469 Episode: Finished after 225 steps
# 470 Episode: Finished after 220 steps
# 471 Episode: Finished after 285 steps
# 472 Episode: Finished after 151 steps
# 473 Episode: Finished after 192 steps
# 474 Episode: Finished after 318 steps
# 475 Episode: Finished after 190 steps
# 476 Episode: Finished after 231 steps
# 477 Episode: Finished after 232 steps
# 478 Episode: Finished after 245 steps
# 479 Episode: Finished after 290 steps
# 480 Episode: Finished after 106 steps
# 481 Episode: Finished after 246 steps
# 482 Episode: Finished after 216 steps
# 483 Episode: Finished after 216 steps
# 484 Episode: Finished after 147 steps
# 485 Episode: Finished after 210 steps
# 486 Episode: Finished after 244 steps
# 487 Episode: Finished after 140 steps
# 488 Episode: Finished after 226 steps
# 489 Episode: Finished after 149 steps
# 490 Episode: Finished after 209 steps
# 491 Episode: Finished after 280 steps
# 492 Episode: Finished after 227 steps
# 493 Episode: Finished after 119 steps
# 494 Episode: Finished after 194 steps
# 495 Episode: Finished after 136 steps
# 496 Episode: Finished after 214 steps
# 497 Episode: Finished after 211 steps
# 498 Episode: Finished after 255 steps
# 499 Episode: Finished after 320 steps
# 500 Episode: Finished after 180 steps
# 501 Episode: Finished after 269 steps
# 502 Episode: Finished after 320 steps
# 503 Episode: Finished after 164 steps
# 504 Episode: Finished after 216 steps
# 505 Episode: Finished after 160 steps
# 506 Episode: Finished after 247 steps
# 507 Episode: Finished after 221 steps
# 508 Episode: Finished after 232 steps
# 509 Episode: Finished after 302 steps
# 510 Episode: Finished after 249 steps
# 511 Episode: Finished after 161 steps
# 512 Episode: Finished after 221 steps
# 513 Episode: Finished after 234 steps
# 514 Episode: Finished after 190 steps
# 515 Episode: Finished after 152 steps
# 516 Episode: Finished after 242 steps
# 517 Episode: Finished after 242 steps
# 518 Episode: Finished after 218 steps
# 519 Episode: Finished after 126 steps
# 520 Episode: Finished after 170 steps
# 521 Episode: Finished after 303 steps
# 522 Episode: Finished after 152 steps
# 523 Episode: Finished after 251 steps
# 524 Episode: Finished after 245 steps
# 525 Episode: Finished after 216 steps
# 526 Episode: Finished after 146 steps
# 527 Episode: Finished after 213 steps
# 528 Episode: Finished after 187 steps
# 529 Episode: Finished after 199 steps
# 530 Episode: Finished after 254 steps
# 531 Episode: Finished after 372 steps
# 532 Episode: Finished after 282 steps
# 533 Episode: Finished after 169 steps
# 534 Episode: Finished after 209 steps
# 535 Episode: Finished after 258 steps
# 536 Episode: Finished after 276 steps
# 537 Episode: Finished after 216 steps
# 538 Episode: Finished after 248 steps
# 539 Episode: Finished after 386 steps
# 540 Episode: Finished after 329 steps
# 541 Episode: Finished after 196 steps
# 542 Episode: Finished after 206 steps
# 543 Episode: Finished after 156 steps
# 544 Episode: Finished after 266 steps
# 545 Episode: Finished after 193 steps
# 546 Episode: Finished after 178 steps
# 547 Episode: Finished after 215 steps
# 548 Episode: Finished after 270 steps
# 549 Episode: Finished after 224 steps
# 550 Episode: Finished after 195 steps
# 551 Episode: Finished after 141 steps
# 552 Episode: Finished after 218 steps
# 553 Episode: Finished after 239 steps
# 554 Episode: Finished after 194 steps
# 555 Episode: Finished after 348 steps
# 556 Episode: Finished after 185 steps
# 557 Episode: Finished after 177 steps
# 558 Episode: Finished after 274 steps
# 559 Episode: Finished after 192 steps
# 560 Episode: Finished after 176 steps
# 561 Episode: Finished after 205 steps
# 562 Episode: Finished after 296 steps
# 563 Episode: Finished after 205 steps
# 564 Episode: Finished after 237 steps
# 565 Episode: Finished after 161 steps
# 566 Episode: Finished after 272 steps
# 567 Episode: Finished after 208 steps
# 568 Episode: Finished after 221 steps
# 569 Episode: Finished after 226 steps
# 570 Episode: Finished after 216 steps
# 571 Episode: Finished after 191 steps
# 572 Episode: Finished after 168 steps
# 573 Episode: Finished after 150 steps
# 574 Episode: Finished after 161 steps
# 575 Episode: Finished after 274 steps
# 576 Episode: Finished after 145 steps
# 577 Episode: Finished after 174 steps
# 578 Episode: Finished after 221 steps
# 579 Episode: Finished after 278 steps
# 580 Episode: Finished after 304 steps
# 581 Episode: Finished after 162 steps
# 582 Episode: Finished after 150 steps
# 583 Episode: Finished after 205 steps
# 584 Episode: Finished after 223 steps
# 585 Episode: Finished after 245 steps
# 586 Episode: Finished after 327 steps
# 587 Episode: Finished after 249 steps
# 588 Episode: Finished after 174 steps
# 589 Episode: Finished after 412 steps
# 590 Episode: Finished after 676 steps
# 591 Episode: Finished after 147 steps
# 592 Episode: Finished after 195 steps
# 593 Episode: Finished after 205 steps
# 594 Episode: Finished after 209 steps
# 595 Episode: Finished after 213 steps
# 596 Episode: Finished after 224 steps
# 597 Episode: Finished after 259 steps
# 598 Episode: Finished after 139 steps
# 599 Episode: Finished after 232 steps
# 600 Episode: Finished after 292 steps
# 601 Episode: Finished after 167 steps
# 602 Episode: Finished after 162 steps
# 603 Episode: Finished after 262 steps
# 604 Episode: Finished after 212 steps
# 605 Episode: Finished after 159 steps
# 606 Episode: Finished after 280 steps
# 607 Episode: Finished after 221 steps
# 608 Episode: Finished after 189 steps
# 609 Episode: Finished after 155 steps
# 610 Episode: Finished after 138 steps
# 611 Episode: Finished after 141 steps
# 612 Episode: Finished after 218 steps
# 613 Episode: Finished after 276 steps
# 614 Episode: Finished after 192 steps
# 615 Episode: Finished after 298 steps
# 616 Episode: Finished after 185 steps
# 617 Episode: Finished after 110 steps
# 618 Episode: Finished after 151 steps
# 619 Episode: Finished after 398 steps
# 620 Episode: Finished after 310 steps
# 621 Episode: Finished after 285 steps
# 622 Episode: Finished after 164 steps
# 623 Episode: Finished after 172 steps
# 624 Episode: Finished after 178 steps
# 625 Episode: Finished after 148 steps
# 626 Episode: Finished after 296 steps
# 627 Episode: Finished after 189 steps
# 628 Episode: Finished after 174 steps
# 629 Episode: Finished after 150 steps
# 630 Episode: Finished after 174 steps
# 631 Episode: Finished after 311 steps
# 632 Episode: Finished after 256 steps
# 633 Episode: Finished after 200 steps
# 634 Episode: Finished after 134 steps
# 635 Episode: Finished after 192 steps
# 636 Episode: Finished after 232 steps
# 637 Episode: Finished after 195 steps
# 638 Episode: Finished after 178 steps
# 639 Episode: Finished after 172 steps
# 640 Episode: Finished after 155 steps
# 641 Episode: Finished after 227 steps
# 642 Episode: Finished after 205 steps
# 643 Episode: Finished after 255 steps
# 644 Episode: Finished after 179 steps
# 645 Episode: Finished after 143 steps
# 646 Episode: Finished after 147 steps
# 647 Episode: Finished after 239 steps
# 648 Episode: Finished after 185 steps
# 649 Episode: Finished after 169 steps
# 650 Episode: Finished after 346 steps
# 651 Episode: Finished after 249 steps
# 652 Episode: Finished after 273 steps
# 653 Episode: Finished after 164 steps
# 654 Episode: Finished after 163 steps
# 655 Episode: Finished after 230 steps
# 656 Episode: Finished after 183 steps
# 657 Episode: Finished after 190 steps
# 658 Episode: Finished after 162 steps
# 659 Episode: Finished after 183 steps
# 660 Episode: Finished after 237 steps
# 661 Episode: Finished after 308 steps
# 662 Episode: Finished after 203 steps
# 663 Episode: Finished after 249 steps
# 664 Episode: Finished after 182 steps
# 665 Episode: Finished after 286 steps
# 666 Episode: Finished after 288 steps
# 667 Episode: Finished after 288 steps
# 669 Episode: Finished after 463 steps
# 670 Episode: Finished after 169 steps
# 671 Episode: Finished after 243 steps
# 672 Episode: Finished after 141 steps
# 673 Episode: Finished after 180 steps
# 674 Episode: Finished after 107 steps
# 675 Episode: Finished after 137 steps
# 676 Episode: Finished after 232 steps
# 677 Episode: Finished after 126 steps
# 678 Episode: Finished after 152 steps
# 679 Episode: Finished after 136 steps
# 680 Episode: Finished after 196 steps
# 681 Episode: Finished after 163 steps
# 682 Episode: Finished after 95 steps
# 683 Episode: Finished after 151 steps
# 684 Episode: Finished after 183 steps
# 685 Episode: Finished after 210 steps
# 686 Episode: Finished after 162 steps
# 687 Episode: Finished after 213 steps
# 688 Episode: Finished after 178 steps
# 689 Episode: Finished after 174 steps
# 690 Episode: Finished after 178 steps
# 691 Episode: Finished after 198 steps
# 692 Episode: Finished after 170 steps
# 693 Episode: Finished after 251 steps
# 694 Episode: Finished after 172 steps
# 695 Episode: Finished after 169 steps
# 696 Episode: Finished after 199 steps
# 697 Episode: Finished after 193 steps
# 698 Episode: Finished after 168 steps
# 699 Episode: Finished after 235 steps
# 700 Episode: Finished after 149 steps
# 701 Episode: Finished after 165 steps
# 702 Episode: Finished after 150 steps
# 703 Episode: Finished after 157 steps
# 704 Episode: Finished after 201 steps
# 705 Episode: Finished after 229 steps
# 706 Episode: Finished after 272 steps
# 707 Episode: Finished after 160 steps
# 708 Episode: Finished after 191 steps
# 709 Episode: Finished after 163 steps
# 710 Episode: Finished after 212 steps
# 711 Episode: Finished after 200 steps
# 712 Episode: Finished after 243 steps
# 713 Episode: Finished after 178 steps
# 714 Episode: Finished after 250 steps
# 715 Episode: Finished after 196 steps
# 716 Episode: Finished after 135 steps
# 717 Episode: Finished after 141 steps
# 718 Episode: Finished after 148 steps
# 719 Episode: Finished after 227 steps
# 720 Episode: Finished after 158 steps
# 721 Episode: Finished after 204 steps
# 722 Episode: Finished after 124 steps
# 723 Episode: Finished after 184 steps
# 724 Episode: Finished after 161 steps
# 725 Episode: Finished after 167 steps
# 726 Episode: Finished after 227 steps
# 727 Episode: Finished after 174 steps
# 728 Episode: Finished after 228 steps
# 729 Episode: Finished after 166 steps
# 730 Episode: Finished after 180 steps
# 731 Episode: Finished after 178 steps
# 732 Episode: Finished after 156 steps
# 733 Episode: Finished after 223 steps
# 734 Episode: Finished after 226 steps
# 735 Episode: Finished after 153 steps
# 736 Episode: Finished after 186 steps
# 737 Episode: Finished after 155 steps
# 738 Episode: Finished after 214 steps
# 739 Episode: Finished after 146 steps
# 740 Episode: Finished after 195 steps
# 741 Episode: Finished after 198 steps
# 742 Episode: Finished after 164 steps
# 743 Episode: Finished after 167 steps
# 744 Episode: Finished after 173 steps
# 745 Episode: Finished after 168 steps
# 746 Episode: Finished after 142 steps
# 747 Episode: Finished after 186 steps
# 748 Episode: Finished after 166 steps
# 749 Episode: Finished after 105 steps
# 750 Episode: Finished after 142 steps
# 751 Episode: Finished after 137 steps
# 752 Episode: Finished after 83 steps
# 753 Episode: Finished after 161 steps
# 754 Episode: Finished after 153 steps
# 755 Episode: Finished after 199 steps
# 756 Episode: Finished after 182 steps
# 757 Episode: Finished after 146 steps
# 758 Episode: Finished after 167 steps
# 759 Episode: Finished after 166 steps
# 760 Episode: Finished after 201 steps
# 761 Episode: Finished after 126 steps
# 762 Episode: Finished after 162 steps
# 763 Episode: Finished after 185 steps
# 764 Episode: Finished after 174 steps
# 765 Episode: Finished after 196 steps
# 766 Episode: Finished after 190 steps
# 767 Episode: Finished after 218 steps
# 768 Episode: Finished after 178 steps
# 769 Episode: Finished after 176 steps
# 770 Episode: Finished after 222 steps
# 771 Episode: Finished after 141 steps
# 772 Episode: Finished after 154 steps
# 773 Episode: Finished after 182 steps
# 774 Episode: Finished after 181 steps
# 775 Episode: Finished after 229 steps
# 776 Episode: Finished after 263 steps
# 777 Episode: Finished after 199 steps
# 778 Episode: Finished after 203 steps
# 779 Episode: Finished after 270 steps
# 780 Episode: Finished after 172 steps
# 781 Episode: Finished after 246 steps
# 782 Episode: Finished after 209 steps
# 783 Episode: Finished after 67 steps
# 784 Episode: Finished after 187 steps
# 785 Episode: Finished after 124 steps
# 786 Episode: Finished after 155 steps
# 787 Episode: Finished after 279 steps
# 788 Episode: Finished after 166 steps
# 789 Episode: Finished after 98 steps
# 790 Episode: Finished after 189 steps
# 791 Episode: Finished after 147 steps
# 792 Episode: Finished after 232 steps
# 793 Episode: Finished after 194 steps
# 794 Episode: Finished after 136 steps
# 795 Episode: Finished after 127 steps
# 796 Episode: Finished after 252 steps
# 797 Episode: Finished after 187 steps
# 798 Episode: Finished after 160 steps
# 799 Episode: Finished after 105 steps
# 800 Episode: Finished after 174 steps
# 801 Episode: Finished after 135 steps
# 802 Episode: Finished after 134 steps
# 803 Episode: Finished after 88 steps
# 804 Episode: Finished after 171 steps
# 805 Episode: Finished after 183 steps
# 806 Episode: Finished after 147 steps
# 807 Episode: Finished after 184 steps
# 808 Episode: Finished after 126 steps
# 809 Episode: Finished after 286 steps
# 810 Episode: Finished after 130 steps
# 811 Episode: Finished after 111 steps
# 812 Episode: Finished after 123 steps
# 813 Episode: Finished after 146 steps
# 814 Episode: Finished after 165 steps
# 815 Episode: Finished after 382 steps
# 816 Episode: Finished after 133 steps
# 817 Episode: Finished after 443 steps
# 818 Episode: Finished after 888 steps
# 819 Episode: Finished after 231 steps
# 820 Episode: Finished after 213 steps
# 821 Episode: Finished after 111 steps
# 822 Episode: Finished after 280 steps
# 823 Episode: Finished after 390 steps
# 824 Episode: Finished after 386 steps
# 825 Episode: Finished after 93 steps
# 826 Episode: Finished after 230 steps
# 827 Episode: Finished after 188 steps
# 828 Episode: Finished after 176 steps
# 829 Episode: Finished after 194 steps
# 830 Episode: Finished after 174 steps
# 831 Episode: Finished after 160 steps
# 832 Episode: Finished after 117 steps
# 833 Episode: Finished after 81 steps
# 834 Episode: Finished after 164 steps
# 835 Episode: Finished after 151 steps
# 836 Episode: Finished after 96 steps
# 837 Episode: Finished after 103 steps
# 838 Episode: Finished after 223 steps
# 839 Episode: Finished after 158 steps
# 840 Episode: Finished after 135 steps
# 841 Episode: Finished after 130 steps
# 842 Episode: Finished after 178 steps
# 843 Episode: Finished after 143 steps
# 844 Episode: Finished after 162 steps
# 845 Episode: Finished after 101 steps
# 846 Episode: Finished after 203 steps
# 847 Episode: Finished after 100 steps
# 848 Episode: Finished after 191 steps
# 849 Episode: Finished after 103 steps
# 850 Episode: Finished after 111 steps
# 851 Episode: Finished after 155 steps
# 852 Episode: Finished after 171 steps
# 853 Episode: Finished after 130 steps
# 854 Episode: Finished after 154 steps
# 855 Episode: Finished after 175 steps
# 856 Episode: Finished after 200 steps
# 857 Episode: Finished after 124 steps
# 858 Episode: Finished after 96 steps
# 859 Episode: Finished after 143 steps
# 860 Episode: Finished after 109 steps
# 861 Episode: Finished after 239 steps
# 862 Episode: Finished after 123 steps
# 863 Episode: Finished after 150 steps
# 864 Episode: Finished after 144 steps
# 865 Episode: Finished after 133 steps
# 866 Episode: Finished after 146 steps
# 867 Episode: Finished after 161 steps
# 868 Episode: Finished after 168 steps
# 869 Episode: Finished after 144 steps
# 870 Episode: Finished after 208 steps
# 871 Episode: Finished after 192 steps
# 872 Episode: Finished after 157 steps
# 873 Episode: Finished after 97 steps
# 874 Episode: Finished after 93 steps
# 875 Episode: Finished after 105 steps
# 876 Episode: Finished after 250 steps
# 877 Episode: Finished after 134 steps
# 878 Episode: Finished after 206 steps
# 879 Episode: Finished after 152 steps
# 880 Episode: Finished after 119 steps
# 881 Episode: Finished after 93 steps
# 882 Episode: Finished after 81 steps
# 883 Episode: Finished after 98 steps
# 884 Episode: Finished after 176 steps
# 885 Episode: Finished after 224 steps
# 886 Episode: Finished after 154 steps
# 887 Episode: Finished after 185 steps
# 888 Episode: Finished after 102 steps
# 889 Episode: Finished after 143 steps
# 890 Episode: Finished after 218 steps
# 891 Episode: Finished after 194 steps
# 892 Episode: Finished after 230 steps
# 893 Episode: Finished after 124 steps
# 894 Episode: Finished after 198 steps
# 895 Episode: Finished after 107 steps
# 896 Episode: Finished after 207 steps
# 897 Episode: Finished after 101 steps
# 898 Episode: Finished after 243 steps
# 899 Episode: Finished after 187 steps
# 900 Episode: Finished after 190 steps
# 901 Episode: Finished after 226 steps
# 902 Episode: Finished after 245 steps
# 903 Episode: Finished after 261 steps
# 904 Episode: Finished after 375 steps
# 905 Episode: Finished after 482 steps
# 906 Episode: Finished after 404 steps
# 907 Episode: Finished after 482 steps
# 908 Episode: Finished after 463 steps
# 909 Episode: Finished after 353 steps
# 910 Episode: Finished after 657 steps
# 911 Episode: Finished after 187 steps
# 912 Episode: Finished after 159 steps
# 913 Episode: Finished after 186 steps
# 914 Episode: Finished after 164 steps
# 915 Episode: Finished after 361 steps
# 916 Episode: Finished after 406 steps
# 918 Episode: Finished after 34 steps
# 919 Episode: Finished after 281 steps
# 920 Episode: Finished after 379 steps
# 921 Episode: Finished after 589 steps
# 922 Episode: Finished after 365 steps
# 923 Episode: Finished after 300 steps
# 924 Episode: Finished after 305 steps
# 925 Episode: Finished after 469 steps
# 926 Episode: Finished after 319 steps
# 927 Episode: Finished after 437 steps
# 928 Episode: Finished after 494 steps
# 929 Episode: Finished after 585 steps
# 930 Episode: Finished after 334 steps
# 931 Episode: Finished after 384 steps
# 932 Episode: Finished after 452 steps
# 933 Episode: Finished after 497 steps
# 連續成功15次!
# 934 Episode: Finished after 570 steps
# ---------------------------------------------------------------------------
# TypeError                                 Traceback (most recent call last)
# Cell In[283], line 3
#       1 #Main
#       2 cartpole_env=Environment()
# ----> 3 cartpole_env.run()
#
# Cell In[282], line 43, in Environment.run(self)
#      40         break
#      42 if is_final is True and step>=300:
# ---> 43     display_frames_as_gif(frames)
#      44     break
#      45 if complete_episodes>=15:
#
# Cell In[279], line 21, in display_frames_as_gif(frames)
#      18 anim=animation.FuncAnimation(plt.gcf(),animate,frames=len(frames), interval=50)
#      20 anim.save('movie_cartpole.mp4')
# ---> 21 display(display_animation(anim, default_mode='loop'))
#
# File /opt/anaconda3/envs/RL_env/lib/python3.11/site-packages/JSAnimation/IPython_display.py:86, in display_animation(anim, **kwargs)
#      84 """Display the animation with an IPython HTML object"""
#      85 from IPython.display import HTML
# ---> 86 return HTML(anim_to_html(anim, **kwargs))
#
# File /opt/anaconda3/envs/RL_env/lib/python3.11/site-packages/JSAnimation/IPython_display.py:74, in anim_to_html(anim, fps, embed_frames, default_mode)
#      69 else:
#      70     # tempfile can't be used here: we need a filename, and this
#      71     # fails on windows.  Instead, we use a custom filename generator
#      72     #with tempfile.NamedTemporaryFile(suffix='.html') as f:
#      73     with _NameOnlyTemporaryFile(suffix='.html') as f:
# ---> 74         anim.save(f.name,  writer=HTMLWriter(fps=fps,
#      75                                              embed_frames=embed_frames,
#      76                                              default_mode=default_mode))
#      77         html = open(f.name).read()
#      79     anim._html_representation = html
#
# File /opt/anaconda3/envs/RL_env/lib/python3.11/site-packages/matplotlib/animation.py:1089, in Animation.save(self, filename, writer, fps, dpi, codec, bitrate, extra_args, metadata, extra_anim, savefig_kwargs, progress_callback)
#    1085 savefig_kwargs['transparent'] = False   # just to be safe!
#    1086 # canvas._is_saving = True makes the draw_event animation-starting
#    1087 # callback a no-op; canvas.manager = None prevents resizing the GUI
#    1088 # widget (both are likewise done in savefig()).
# -> 1089 with writer.saving(self._fig, filename, dpi), \
#    1090      cbook._setattr_cm(self._fig.canvas, _is_saving=True, manager=None):
#    1091     for anim in all_anim:
#    1092         anim._init_draw()  # Clear the initial frame
#
# File /opt/anaconda3/envs/RL_env/lib/python3.11/contextlib.py:137, in _GeneratorContextManager.__enter__(self)
#     135 del self.args, self.kwds, self.func
#     136 try:
# --> 137     return next(self.gen)
#     138 except StopIteration:
#     139     raise RuntimeError("generator didn't yield") from None
#
# File /opt/anaconda3/envs/RL_env/lib/python3.11/site-packages/matplotlib/animation.py:240, in AbstractMovieWriter.saving(self, fig, outfile, dpi, *args, **kwargs)
#     235     _log.info("Disabling savefig.bbox = 'tight', as it may cause "
#     236               "frame size to vary, which is inappropriate for "
#     237               "animation.")
#     239 # This particular sequence is what contextlib.contextmanager wants
# --> 240 self.setup(fig, outfile, dpi, *args, **kwargs)
#     241 with mpl.rc_context({'savefig.bbox': None}):
#     242     try:
#
# File /opt/anaconda3/envs/RL_env/lib/python3.11/site-packages/JSAnimation/html_writer.py:281, in HTMLWriter.setup(self, fig, outfile, dpi, frame_dir)
#     278 else:
#     279     frame_prefix = None
# --> 281 super(HTMLWriter, self).setup(fig, outfile, dpi,
#     282                               frame_prefix, clear_temp=False)
#
# TypeError: FileMovieWriter.setup() got an unexpected keyword argument 'clear_temp'
